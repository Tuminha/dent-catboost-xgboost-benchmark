# %% [markdown]
# # 01: EDA and Labeling
#
# ## Objectives
# - Inspect distribution of target and class imbalance
# - Missingness heatmap; cardinality of categoricals; top-k categories
# - Decide: imputation strategy; leaky columns; time split vs stratified
# - **Brand-style plots start here**

# %%
# TODO: Import branding and apply brand style
# from src.branding import use_brand_style, savefig_brand
# use_brand_style()

# %%
# TODO: Load cfg + dataset; basic clean
# from src.data_io import load_cfg, load_dataset
# from src.features import basic_clean
# 
# cfg = load_cfg()
# df = load_dataset()
# df_clean = basic_clean(df, cfg)

# %%
# TODO: Plot class ratio bar (brand-styled)
# import matplotlib.pyplot as plt
# 
# # Plot target distribution
# # Use brand colors from src.branding
# # Save with savefig_brand("images/01_target_distribution.png")

# %%
# TODO: Plot a couple of brand-styled histograms/boxen by target
# import seaborn as sns
# 
# # Example: numeric feature distribution by target
# # Use brand colors, save to images/

# %%
# TODO: Build lists: cat_cols, num_cols; compute simple target mean by category
# cat_cols = []
# num_cols = []
# 
# # For each categorical: df.groupby('cat_col')[target].mean()

# %%
# TODO: Plot class ratio bar (brand-styled)
# import matplotlib.pyplot as plt
# 
# # Plot target distribution
# # Use brand colors from src.branding
# # Save with savefig_brand("images/01_target_distribution.png")

# %%
# TODO: Plot a couple of brand-styled histograms/boxen by target
# import seaborn as sns
# 
# # Example: numeric feature distribution by target
# # Use brand colors, save to images/

# %%
# TODO: Build lists: cat_cols, num_cols; compute simple target mean by category
# cat_cols = []
# num_cols = []
# 
# # For each categorical: df.groupby('cat_col')[target].mean()
