# %% [markdown]
# # 01: EDA and Labeling
#
# ## Objectives
# - This dataset is binary. Inspect class balance: value counts on target
# - Quick missingness matrix and cardinality of categoricals
# - Brand-styled plots saved to `images/`

# %%
# TODO: Import branding and apply brand style
# from src.branding import use_brand_style, savefig_brand
# use_brand_style()

# %%
# TODO: Load cfg + dataset; basic clean
# from src.data_io import load_cfg, load_dataset
# from src.features import basic_clean
# 
# cfg = load_cfg()
# df = load_dataset()
# df_clean = basic_clean(df, cfg)

# %%
# TODO: Plot class ratio bar (brand-styled)
# import matplotlib.pyplot as plt
# 
# # Plot target distribution
# # Use brand colors from src.branding
# # Save with savefig_brand("images/01_target_distribution.png")

# %%
# TODO: Save 2–3 plots: class ratio bar; a couple of category vs target bar plots
# import matplotlib.pyplot as plt
# import seaborn as sns
# from src.branding import savefig_brand
# 
# # Plot 1: Class ratio bar (brand-styled)
# # y.value_counts().plot(kind='bar', ...)
# # savefig_brand("images/01_target_distribution.png")
# 
# # Plot 2-3: Category vs target bar plots
# # For a couple of categoricals: df.groupby('cat_col')[target].mean().plot(...)
# # Use brand colors, save to images/
