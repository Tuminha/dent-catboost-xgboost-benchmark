# %% [markdown]
# # 04: SHAP and Segment Findings
#
# ## Objectives
# - Use SHAP to explain CatBoost (faster, native)
# - Deliver two views:
#   1. Global summary (top drivers)
#   2. Per-segment comparison (e.g., by region/age_bracket if available)
# - Save plots under `images/`

# %%
# TODO: Sample 1–2k rows for SHAP; call shap_summary_catboost
# from src.explain import shap_summary_catboost
# import numpy as np
# 
# # Sample rows
# sample_idx = np.random.choice(len(X_test), size=min(2000, len(X_test)), replace=False)
# X_sample = X_test.iloc[sample_idx]
# 
# shap_summary_catboost(model_cat, X_sample, "images/04_shap_summary.png")

# %%
# TODO: Compute simple partial-dependence style plots for 2–3 key features (hint only)
# # Use SHAP partial dependence or sklearn's partial_dependence
# # Plot with brand style, save to images/
