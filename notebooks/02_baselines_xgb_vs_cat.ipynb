# %% [markdown]
# # 02: Baselines - XGBoost vs CatBoost
#
# ## Objectives
# - Set up CatBoost with native categoricals
# - Set up XGBoost with one of:
#   - One-hot encoding (if small cardinality), or
#   - Target encoding (explain leakage guard via CV)
# - Train/valid split; metric: PR-AUC primary

# %%
# TODO: Create train/test according to cfg
# from src.features import split_train_test
# 
# X_train, X_test, y_train, y_test = split_train_test(df_clean, y, cfg)

# %%
# TODO: CatBoost - build model with cat_idx (list of column indices)
# from src.modeling import build_catboost
# 
# # Get categorical column indices
# cat_idx = [X_train.columns.get_loc(col) for col in cfg['categoricals']]
# 
# model_cat = build_catboost(cat_idx, cfg)
# # Fit with eval set
# # model_cat.fit(X_train, y_train, eval_set=(X_test, y_test), ...)

# %%
# TODO: XGBoost baseline - simple preprocessing pipeline
# from src.modeling import build_xgboost
# from sklearn.preprocessing import OneHotEncoder
# 
# # Hint: OneHotEncoder(handle_unknown="ignore") or leave TODO to try target encoding later
# # Preprocess X_train, X_test for XGBoost
# 
# model_xgb = build_xgboost(cfg)
# # model_xgb.fit(X_train_processed, y_train, ...)

# %%
# TODO: For both: get y_prob on test; call prob_to_metrics; print compact comparison table
# from src.evaluation import prob_to_metrics
# 
# y_prob_cat = model_cat.predict_proba(X_test)[:, 1]
# y_prob_xgb = model_xgb.predict_proba(X_test_processed)[:, 1]
# 
# metrics_cat = prob_to_metrics(y_test, y_prob_cat)
# metrics_xgb = prob_to_metrics(y_test, y_prob_xgb)
# 
# # Print comparison table
