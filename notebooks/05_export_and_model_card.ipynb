# %% [markdown]
# # 05: Export and Model Card
#
# ## Competition Context
# **Kaggle Competition**: [Predicting Dental Visits](https://www.kaggle.com/competitions/predicting-dental-visits)
#
# **Prediction Task**: Binary classification to predict whether a person had a dental visit in the last 12 months.
#
# ## Objectives
# - Persist both models; generate model_card.md summarizing the competition context and local metrics
# - Include metric table and brand images

# %%
# TODO: joblib.dump both models to artifacts/models/
# import joblib
# from pathlib import Path
# 
# Path("artifacts/models").mkdir(parents=True, exist_ok=True)
# joblib.dump(model_cat, "artifacts/models/catboost_best.pkl")
# joblib.dump(model_xgb, "artifacts/models/xgboost_best.pkl")

# %%
# TODO: Write artifacts/reports/model_card.md from a template string with placeholders
# model_card_template = """
# # Model Card — Dental Tabular Classifier (CatBoost vs XGBoost)
# 
# **Intended use**: educational benchmark for dental tabular data (non-clinical).
# 
# **Competition**: Kaggle "Predicting Dental Visits"
# 
# **Data**: <dataset name>, rows=<n>, features=<m>, period=<years>.
# Dataset files: train.csv, test.csv, sample_submission.csv
# 
# **Target**: <binary definition>, positive_class=<value>.
# 
# **Train/Validation**: <CV type>, Test split: <time/stratified>.
# 
# **Metrics**: PR-AUC=<>, ROC-AUC=<>, Recall@T=<>, Precision@T=<>.
# 
# **Top drivers (SHAP)**: <bullets>.
# 
# **Limits**: may encode platform/demographics effects; not a medical device; not for treatment decisions.
# 
# **Safety**: no PHI stored; dataset license respected.
# 
# **How to reproduce**: run notebooks 00 → 05 with `config/dataset.yaml`.
# """
# 
# # Fill in placeholders and write to artifacts/reports/model_card.md

# %%
# TODO: Copy best plots from images/ into artifacts/reports/
# import shutil
# from pathlib import Path
# 
# # Copy selected images to artifacts/reports/
