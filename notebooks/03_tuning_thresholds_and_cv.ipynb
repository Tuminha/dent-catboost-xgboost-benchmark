# %% [markdown]
# # 03: Tuning Thresholds and Cross-Validation
#
# ## Competition Context
# **Kaggle Competition**: [Predicting Dental Visits](https://www.kaggle.com/competitions/predicting-dental-visits)
#
# **Prediction Task**: Binary classification to predict whether a person had a dental visit in the last 12 months.
#
# ## Objectives
# - K-fold CV (StratifiedKFold) to evaluate model performance on dental visit prediction
# - Optional Optuna sweep for each model (small trial budget)
# - Choose a policy threshold (maximize recall subject to min precision), for interpretability only. Kaggle submission will still be probabilities

# %%
# TODO: Build CV using scikit-learn; track PR-AUC mean/std
# from sklearn.model_selection import StratifiedKFold
# from sklearn.metrics import average_precision_score
# 
# skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
# # Track PR-AUC for each fold

# %%
# TODO: Minimal Optuna study (TODO: sampler, objective skeleton)
# import optuna
# 
# def objective(trial):
#     # Suggest hyperparameters
#     # Train model
#     # Return CV score
#     pass
# 
# study = optuna.create_study(direction='maximize')
# study.optimize(objective, n_trials=30)

# %%
# TODO: Refit chosen hyperparams on full training set (except test)
# import json
# from pathlib import Path
# 
# # Refit with best params on full training set (except holdout test)
# # Evaluate on test set
# # Save best models and metrics JSON
# Path("artifacts/reports").mkdir(parents=True, exist_ok=True)
# # Save metrics to artifacts/reports/metrics.json
