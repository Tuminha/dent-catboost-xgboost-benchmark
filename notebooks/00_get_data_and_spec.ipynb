# %% [markdown]
# # 00: Get Data and Specification
#
# ## Competition Context
# **Kaggle Competition**: [Predicting Dental Visits](https://www.kaggle.com/competitions/predicting-dental-visits)
#
# **Prediction Task**: Binary classification to predict whether a person had a dental visit in the last 12 months.
#
# ## Purpose
# This notebook downloads (optional) and validates **Predicting Dental Visits** competition files, then configures `config/dataset.yaml` with the correct target column and feature specifications.
#
# ## Checklist
# - [ ] Confirm target column name in train.csv (the binary outcome: dental visit in last 12 months)
# - [ ] Confirm ID column name in both train.csv and test.csv
# - [ ] List categorical columns (put them into config/dataset.yaml)
# - [ ] Update `config/dataset.yaml` with correct paths and settings

# %%
# TODO: Verify Kaggle is available, or skip
# import kaggle
# from kaggle.api.kaggle_api_extended import KaggleApi
# api = KaggleApi()
# api.authenticate()

import pandas as pd
import kaggle
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

# %%
# TODO: Print dataset path and first 5 rows
# import pandas as pd
# from pathlib import Path
# 
# data_path = Path("data/raw/REPLACE_ME.csv")
# df = pd.read_csv(data_path)
# print(f"Dataset shape: {df.shape}")
# print(f"\nFirst 5 rows:")
# df.head()

# %%
# TODO: Edit dataset.yaml in-place (tiny YAML write snippet or manual)
# import yaml
# from pathlib import Path
# 
# cfg_path = Path("config/dataset.yaml")
# cfg = yaml.safe_load(cfg_path.read_text())
# 
# # Update with your findings:
# # cfg['file'] = "data/raw/your_file.csv"
# # cfg['target'] = "your_target_column"
# # cfg['positive_class'] = 1  # or "Yes"
# # cfg['categoricals'] = ["col1", "col2"]
# 
# # yaml.dump(cfg, cfg_path.open('w'), default_flow_style=False)
